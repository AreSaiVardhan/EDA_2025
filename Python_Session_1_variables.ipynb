# %%
num=100
num
# Out:
# 100

# %%
num=200
num
# Out:
# 200

# %%
num
# Out:
# 200

# %% [markdown]
# - python is step by step process
#
# - python will consider latest value
#
# - num=200 is the latest

# %%
id(num)
# Out:
# 140729089514504

# %%
number=100
NUMBER=200

# %%
number
# Out:
# 100

# %%
NUMBER
# Out:
# 200

# %% [markdown]
# - python is case sensitive

# %%
number123=100
number123
# Out:
# 100

# %%
123number=200
123number
# Out:
#   Cell In[10], line 1
#     123number=200
#       ^
# SyntaxError: invalid decimal literal

# %%
number%one=300
number%one
# Out:
#   Cell In[11], line 1
#     number%one=300
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
number one=400
number one
# Out:
#   Cell In[12], line 1
#     number one=400
#            ^
# SyntaxError: invalid syntax

# %%
number_one=500
number_one
# Out:
# 500

# %%
print=40
print
# Out:
# 40

# %%
print # is used for only printing to see the value
type  # is used to check only the type of the data
sum   # sum is used to get the total sum of elements in an array
max   # max is used to get the max value of elements in an array
min   # min is used to get the min value of elements in an array

# %% [markdown]
# - Must start with a letter A-Z or a-z or an underscore
#
# - can contain letters , numbers as suffix and underscore
#
# - Only underscore can be allowed
#
# - keywords or reserved words are not allowed
#
# - do not use inbuilt functions eventough it works

# %%
import os
os.getcwd()   # getcwd - get current working directory
# Out:
# 'C:\\Users\\HP\\Documents\\Python with GENAI\\Python_Sessions'
